# %%
class Robot:
    def __init__(self, r, c, office):
        self.r = r
        self.c = c
        self.office = office
        self.total = self.office[r][c]
        self.heading = 'N'
        self.office[r][c] = 0

        

    def go(self):
        if self.heading == 'N':
            if self.r - 1 >= 0 and self.office[self.r - 1][self.c] != -1:
                self.r -= 1
                self.clean(self.r, self.c)
        elif self.heading == 'S':
            if self.r + 1 <= len(self.office) and self.office[self.r + 1][self.c] != -1:
                self.r += 1
                self.clean(self.r, self.c)
        elif self.heading == 'E':
            if self.c + 1 <= len(self.office) and self.office[self.r][self.c + 1] != -1:
                self.c += 1
                self.clean(self.r, self.c)
                
        elif self.heading == 'W':
            if self.c - 1 >= 0 and self.office[self.r][self.c - 1] != -1:
                self.c -= 1
                self.clean(self.r, self.c)
        print(self.office)

    def left(self):
        if self.heading == 'N':
            self.heading = 'W'
        elif self.heading == 'S':
            self.heading = 'E'
        elif self.heading == 'E':
            self.heading = 'N'
        else:
            self.heading = 'S'
            
    def right(self):
        if self.heading == 'N':
            self.heading = 'E'
        elif self.heading == 'S':
            self.heading = 'W'
        elif self.heading == 'E':
            self.heading = 'S'
        else:
            self.heading = 'N'
    
    def clean(self, r, c):
        self.total += self.office[r][c]
        self.office[r][c] = 0
        
def solution(office, r, c, move):
    total = 0
    robot = Robot(r, c, office)
    for cmd in move:
        if cmd =='go':
            robot.go()
        elif cmd == 'left':
            robot.left()
        elif cmd == 'right':
            robot.right()
    
    total = robot.total
    
    return total

solution([[5,-1,-1],[6,3,-1],[2,-1,1]], 1, 0, ['go','go','right','go','right','go','left','go'])
# Out:
# [[0, -1, -1], [0, 3, -1], [2, -1, 1]]
# [[0, -1, -1], [0, 3, -1], [2, -1, 1]]
# [[0, -1, -1], [0, 3, -1], [2, -1, 1]]
# [[0, -1, -1], [0, 3, -1], [2, -1, 1]]
# [[0, -1, -1], [0, 0, -1], [2, -1, 1]]
# 14

# %%
class Robot:
    def __init__(self, r, c, office):
        self.r = r
        self.c = c
        self.office = office
        self.total = self.office[r][c]
        self.heading = 'N'
        self.office[r][c] = 0

        

    def go(self):
        if self.heading == 'N':
            if self.r - 1 >= 0 and self.office[self.r - 1][self.c] != -1:
                self.r -= 1
                self.clean(self.r, self.c)
        elif self.heading == 'S':
            if self.r + 1 <= len(self.office) - 1 and self.office[self.r + 1][self.c] != -1:
                self.r += 1
                self.clean(self.r, self.c)
        elif self.heading == 'E':
            if self.c + 1 <= len(self.office) - 1 and self.office[self.r][self.c + 1] != -1:
                self.c += 1
                self.clean(self.r, self.c)
                
        elif self.heading == 'W':
            if self.c - 1 >= 0 and self.office[self.r][self.c - 1] != -1:
                self.c -= 1
                self.clean(self.r, self.c)
        print(self.office)

    def left(self):
        if self.heading == 'N':
            self.heading = 'W'
        elif self.heading == 'S':
            self.heading = 'E'
        elif self.heading == 'E':
            self.heading = 'N'
        else:
            self.heading = 'S'
            
    def right(self):
        if self.heading == 'N':
            self.heading = 'E'
        elif self.heading == 'S':
            self.heading = 'W'
        elif self.heading == 'E':
            self.heading = 'S'
        else:
            self.heading = 'N'
    
    def clean(self, r, c):
        self.total += self.office[r][c]
        self.office[r][c] = 0
        
def solution(office, r, c, move):
    total = 0
    print(office)
    robot = Robot(r, c, office)

    for cmd in move:
        if cmd =='go':
            robot.go()
        elif cmd == 'left':
            robot.left()
        elif cmd == 'right':
            robot.right()
    
    total = robot.total
    
    return total

solution([[5,-1,-1],[6,3,-1],[2,-1,1]], 2, 2, ['go','go','right','go','right','go','left','go'])
# Out:
# [[5, -1, -1], [6, 3, -1], [2, -1, 1]]
# [[5, -1, -1], [6, 3, -1], [2, -1, 0]]
# [[5, -1, -1], [6, 3, -1], [2, -1, 0]]
# [[5, -1, -1], [6, 3, -1], [2, -1, 0]]
# [[5, -1, -1], [6, 3, -1], [2, -1, 0]]
# [[5, -1, -1], [6, 3, -1], [2, -1, 0]]
# 1

# %%
class Robot:
    def __init__(self, r, c, office):
        self.r = r
        self.c = c
        self.office = office
        self.total = self.office[r][c]
        self.heading = 'N'
        self.office[r][c] = 0

        

    def go(self):
        if self.heading == 'N':
            if self.r - 1 >= 0 and self.office[self.r - 1][self.c] != -1:
                self.r -= 1
                self.clean(self.r, self.c)
        elif self.heading == 'S':
            if self.r + 1 <= len(self.office):
                try:
                    if self.office[self.r + 1][self.c] != -1:
                finally:
                    self.r += 1
                    self.clean(self.r, self.c)
        elif self.heading == 'E':
            if self.c + 1 <= len(self.office) and self.office[self.r][self.c + 1] != -1:
                try:
                    if self.office[self.r][self.c + 1] != -1:
                finally:
                    self.c += 1
                    self.clean(self.r, self.c)
                
        elif self.heading == 'W':
            if self.c - 1 >= 0 and self.office[self.r][self.c - 1] != -1:
                self.c -= 1
                self.clean(self.r, self.c)
        print(self.office)

    def left(self):
        if self.heading == 'N':
            self.heading = 'W'
        elif self.heading == 'S':
            self.heading = 'E'
        elif self.heading == 'E':
            self.heading = 'N'
        else:
            self.heading = 'S'
            
    def right(self):
        if self.heading == 'N':
            self.heading = 'E'
        elif self.heading == 'S':
            self.heading = 'W'
        elif self.heading == 'E':
            self.heading = 'S'
        else:
            self.heading = 'N'
    
    def clean(self, r, c):
        self.total += self.office[r][c]
        self.office[r][c] = 0
        
def solution(office, r, c, move):
    total = 0
    robot = Robot(r, c, office)
    for cmd in move:
        if cmd =='go':
            robot.go()
        elif cmd == 'left':
            robot.left()
        elif cmd == 'right':
            robot.right()
    
    total = robot.total
    
    return total

solution([[5,-1,-1],[0,-1,-1],[2,-1,1]], 2, 2, ['go','go','right','go','right','go','left','go'])
# Out:
#   File "<ipython-input-17-38e298faf016>", line 21
#     finally:
#     ^
# IndentationError: expected an indented block
